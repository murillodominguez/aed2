# %% [markdown]
# ### 1. Implemente uma lista para gerenciar o estoque de uma loja. Cada nodo deve ser um objeto da classe Produto (com atributos nome e preço).
#
# a. **Operações**: iniciar(max), inserir(posicao, produto),
# remover(posicao), buscar_por_nome(nome) e
# limpar_lista().
#
# b. Desafio: No método limpar_lista(), certifique-se de que os
# índices ini e fim voltem ao estado original de lista vazia.
